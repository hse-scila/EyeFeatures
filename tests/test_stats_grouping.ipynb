# %%
import os
from os.path import join

import numpy as np
import pandas as pd

# %%
DATA_PATH = join("..", "data", "Dyslexia_1_ready_data_fixations.csv")

# %%
def read_dataset(path: str = DATA_PATH):
    df = pd.read_csv(path, index_col="Unnamed: 0")
    
    df["SentenceID"] = df["Sentence_ID"]
    df["x"] = df["FIX_X"].apply(lambda x: float(x.replace(",", ".")))
    df["y"] = df["FIX_Y"].apply(lambda x: float(x.replace(",", ".")))
    df.x /= df.x.max()
    df.y /= df.y.max()
    df["duration"] = df["FIX_DURATION"].apply(lambda x: float(x) / 1000)
    df["timestamp"] = df.duration.cumsum()
    df["AOI_1"] = np.random.choice([0, 1], size=len(df))
    df["AOI_2"] = np.random.choice([11, 22, 33], size=len(df))
    df["AOI_3"] = np.random.choice(['A', 'B', 'C'], size=len(df))
    
    df.drop(["Word_Number", "IQ", "FIX_X", "FIX_Y", "FIX_DURATION", "Age", "Sentence_ID"], axis=1, inplace=True)
    return df

# %%
df = read_dataset()
df.head()
# Out:
#   SubjectID  Group  Sex  SentenceID         x         y  duration  timestamp  \
# 0      nnr8      3  fem          27  0.101158  0.726088     0.345      0.345
# 1      nnr8      3  fem          27  0.102406  0.754083     0.221      0.566
# 2      nnr8      3  fem          27  0.126049  0.755455     0.204      0.770
# 3      nnr8      3  fem          27  0.142134  0.761356     0.289      1.059
# 4      nnr8      3  fem          27  0.109963  0.766433     0.600      1.659
#
#    AOI_1  AOI_2 AOI_3
# 0      1     11     B
# 1      1     11     C
# 2      0     11     C
# 3      0     22     A
# 4      1     33     B

# %% [markdown]
# ### 0. `Extractor` над нормальным датасетом.

# %%
import eyefeatures.features.stats as eye_stats
from eyefeatures.features.extractor import Extractor

sac_feats_stats = {
    'length': ['min', 'max'],
    'acceleration': ['mean']
}

sac_feats_stats_shift = {
    'acceleration': ['mean']
}

sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=['SentenceID']
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    pk=['SubjectID', 'SentenceID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.44it/s]
#          sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26_4        0.007354        0.129626               0.662910
# nnr26_5        0.018238        0.114133               0.631904
# nnr26_6        0.020591        0.157276               0.785294
# nnr26_7        0.021866        0.164827               0.522326
# nnr26_8        0.031671        0.127567               0.598728
#
#          sac_acceleration_mean_shift_SentenceID
# nnr26_4                               -0.147094
# nnr26_5                               -0.006173
# nnr26_6                               -0.080868
# nnr26_7                               -0.232872
# nnr26_8                               -0.096059

# %% [markdown]
# ### 1. Обработка `NaN`. Ожидается: читать changes.md.

# %%
dfn = df.copy()
dfn.loc[0, "x"] = None
dfn.loc[0, "y"] = np.nan
extractor.fit_transform(dfn).head()
# Out:
# /tmp/ipykernel_7351/889556869.py:4: UserWarning: Group nnr8_27 has missing values. Dropping them.
#   extractor.fit_transform(dfn).head()
# 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
#          sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26_4        0.007354        0.129626               0.662910
# nnr26_5        0.018238        0.114133               0.631904
# nnr26_6        0.020591        0.157276               0.785294
# nnr26_7        0.021866        0.164827               0.522326
# nnr26_8        0.031671        0.127567               0.598728
#
#          sac_acceleration_mean_shift_SentenceID
# nnr26_4                               -0.147094
# nnr26_5                               -0.006173
# nnr26_6                               -0.080868
# nnr26_7                               -0.232872
# nnr26_8                               -0.096059

# %%
dfn.loc[0, "SubjectID"] = None
try:
    extractor.fit_transform(dfn).head()
except ValueError as e:
    print(e)
    print("OK")
# Out:
# Found missing values in pk.
# OK

# %% [markdown]
# ### 2. Несколько `shift_pk` и проверка, что можно не подмножество `pk`.

# %% [markdown]
# #### 2.0. Дефолтные случаи.

# %% [markdown]
# ##### 2.0.0. Дефолтный случай `pk=None`, `shift_features=None`. Ожидается: одна строка и 3 фичи.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    # shift_features=sac_feats_stats_shift,
    # shift_pk=['SentenceID']
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    # pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 528.25it/s]
#    sac_length_min  sac_length_max  sac_acceleration_mean
# 0             0.0        1.255172               14.24703

# %% [markdown]
# ##### 2.0.1. Дефолтный случай `pk=...`, `shift_features=None`. Ожидается: 3 фичи.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    # shift_features=sac_feats_stats_shift,
    # shift_pk=['SentenceID']
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    pk=['SubjectID', 'SentenceID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]
#          sac_length_min  sac_length_max  sac_acceleration_mean
# nnr26_4        0.007354        0.129626               0.662910
# nnr26_5        0.018238        0.114133               0.631904
# nnr26_6        0.020591        0.157276               0.785294
# nnr26_7        0.021866        0.164827               0.522326
# nnr26_8        0.031671        0.127567               0.598728

# %% [markdown]
# #### 2.1. Можно `shift_pk` не подмножество `shift_features`.

# %% [markdown]
# ##### 2.1.1. Можно `shift_pk` не подмножество `shift_features`. Ожидается: 3 фичи + 1 shift фича.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=['SentenceID']
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 28.37it/s]
#        sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26        0.000981        1.242229               1.006598
# nnr27        0.000098        1.223697               0.661369
# nnr33        0.001667        1.218795               8.554904
# nnr36        0.000000        1.108976               0.522238
# nnr41        0.000098        1.202714             211.992586
#
#        sac_acceleration_mean_shift_SentenceID
# nnr26                               -2.224055
# nnr27                               -1.484686
# nnr33                                6.793463
# nnr36                               -2.474636
# nnr41                              208.564133

# %% [markdown]
# #### 2.2. Комбинации `shift_pk` и `shift_features`.

# %% [markdown]
# ##### 2.2.1. Можно несколько `shift_pk` на один `shift_features`. Ожидается: 3 фичи + 3 shift фичи.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=(['SentenceID', 'SubjectID'], ['SentenceID'], ['SubjectID'])
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12.20it/s]
#        sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26        0.000981        1.242229               1.006598
# nnr27        0.000098        1.223697               0.661369
# nnr33        0.001667        1.218795               8.554904
# nnr36        0.000000        1.108976               0.522238
# nnr41        0.000098        1.202714             211.992586
#
#        sac_acceleration_mean_shift_SentenceID_SubjectID  \
# nnr26                                          0.246305
# nnr27                                          0.225492
# nnr33                                          7.992622
# nnr36                                          0.142837
# nnr41                                        210.547696
#
#        sac_acceleration_mean_shift_SentenceID  \
# nnr26                               -2.224055
# nnr27                               -1.484686
# nnr33                                6.793463
# nnr36                               -2.474636
# nnr41                              208.564133
#
#        sac_acceleration_mean_shift_SubjectID
# nnr26                           0.000000e+00
# nnr27                          -1.110223e-16
# nnr33                           0.000000e+00
# nnr36                           0.000000e+00
# nnr41                           0.000000e+00

# %% [markdown]
# ##### 2.2.2. Можно несколько `shift_pk` и несколько `shift_features`. Ожидается: 3 фичи + 3 shift фичи.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats={'length': ['min', 'max', 'median']},
    shift_features=({'length': ['min']}, {'length': ['max', 'median']}),
    shift_pk=(['SentenceID', 'SubjectID'], ['SentenceID'])
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 20.12it/s]
#        sac_length_min  sac_length_max  sac_length_median  \
# nnr26        0.000981        1.242229           0.058783
# nnr27        0.000098        1.223697           0.051674
# nnr33        0.001667        1.218795           0.050595
# nnr36        0.000000        1.108976           0.031622
# nnr41        0.000098        1.202714           0.065695
#
#        sac_length_min_shift_SentenceID_SubjectID  \
# nnr26                                  -0.015779
# nnr27                                  -0.012229
# nnr33                                  -0.012024
# nnr36                                  -0.005636
# nnr41                                  -0.010350
#
#        sac_length_max_shift_SentenceID  sac_length_median_shift_SentenceID
# nnr26                         0.259375                            0.008595
# nnr27                         0.234035                            0.001828
# nnr33                         0.227801                            0.000759
# nnr36                         0.125408                           -0.017750
# nnr41                         0.224268                            0.015378

# %% [markdown]
# ### 3. Можно несколько разных `AOI` колонок.

# %% [markdown]
# #### 3.0. Дефолтные случаи.

# %% [markdown]
# ##### 3.0.1. `aoi=None`. Ожидается: 3 фичи + 2 shift фичи.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=(['SentenceID'], ['SubjectID'])
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    aoi=None,
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 18.80it/s]
#        sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26        0.000981        1.242229               1.006598
# nnr27        0.000098        1.223697               0.661369
# nnr33        0.001667        1.218795               8.554904
# nnr36        0.000000        1.108976               0.522238
# nnr41        0.000098        1.202714             211.992586
#
#        sac_acceleration_mean_shift_SentenceID  \
# nnr26                               -2.224055
# nnr27                               -1.484686
# nnr33                                6.793463
# nnr36                               -2.474636
# nnr41                              208.564133
#
#        sac_acceleration_mean_shift_SubjectID
# nnr26                           0.000000e+00
# nnr27                          -1.110223e-16
# nnr33                           0.000000e+00
# nnr36                           0.000000e+00
# nnr41                           0.000000e+00

# %% [markdown]
# #### 3.1. Одно и более значений `AOI` + `calc_without_aoi`.

# %% [markdown]
# ##### 3.1.1. Одно значение `AOI`. Ожидается: (3 фичи + 2 shift фичи) x 2 для `AOI_1=0` и `AOI_1=1`.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=(['SentenceID'], ['SubjectID'])
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    aoi='AOI_1',
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  7.93it/s]
#        sac_length_AOI_1[1]_min  sac_length_AOI_1[1]_max  \
# nnr26                 0.007354                 0.975820
# nnr27                 0.006668                 1.223697
# nnr33                 0.003138                 0.890220
# nnr36                 0.000392                 0.996313
# nnr41                 0.000294                 1.115643
#
#        sac_acceleration_AOI_1[1]_mean  \
# nnr26                        0.755757
# nnr27                        0.664412
# nnr33                       29.681030
# nnr36                        0.338206
# nnr41                        2.166084
#
#        sac_acceleration_AOI_1[1]_mean_shift_SentenceID  \
# nnr26                                        -0.077476
# nnr27                                        -0.145907
# nnr33                                        28.878591
# nnr36                                        -0.462028
# nnr41                                         1.321617
#
#        sac_acceleration_AOI_1[1]_mean_shift_SubjectID  \
# nnr26                                             0.0
# nnr27                                             0.0
# nnr33                                             0.0
# nnr36                                             0.0
# nnr41                                             0.0
#
#        sac_length_AOI_1[0]_min  sac_length_AOI_1[0]_max  \
# nnr26                 0.003824                 1.084462
# nnr27                 0.003726                 0.994940
# nnr33                 0.003334                 0.931010
# nnr36                 0.000000                 1.013276
# nnr41                 0.000098                 0.976506
#
#        sac_acceleration_AOI_1[0]_mean  \
# nnr26                        0.966335
# nnr27                        0.661719
# nnr33                        1.564360
# nnr36                        0.503107
# nnr41                       17.153674
#
#        sac_acceleration_AOI_1[0]_mean_shift_SentenceID  \
# nnr26                                         0.065272
# nnr27                                        -0.217515
# nnr33                                         0.641526
# nnr36                                        -0.355475
# nnr41                                        16.254921
#
#        sac_acceleration_AOI_1[0]_mean_shift_SubjectID
# nnr26                                             0.0
# nnr27                                             0.0
# nnr33                                             0.0
# nnr36                                             0.0
# nnr41                                             0.0

# %% [markdown]
# ##### 3.1.2. Одно значение `AOI`. Ожидается: (3 фичи + 2 shift фичи) x (1 + 2) для `calc_with_aoi=True`, `AOI_1=0` и `AOI_1=1`.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats=sac_feats_stats,
    shift_features=sac_feats_stats_shift,
    shift_pk=(['SentenceID'], ['SubjectID']),
    calc_without_aoi=True
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    aoi='AOI_1',
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  6.16it/s]
#        sac_length_min  sac_length_max  sac_acceleration_mean  \
# nnr26        0.000981        1.242229               1.006598
# nnr27        0.000098        1.223697               0.661369
# nnr33        0.001667        1.218795               8.554904
# nnr36        0.000000        1.108976               0.522238
# nnr41        0.000098        1.202714             211.992586
#
#        sac_acceleration_mean_shift_SentenceID  \
# nnr26                               -2.224055
# nnr27                               -1.484686
# nnr33                                6.793463
# nnr36                               -2.474636
# nnr41                              208.564133
#
#        sac_acceleration_mean_shift_SubjectID  sac_length_AOI_1[1]_min  \
# nnr26                           0.000000e+00                 0.007354
# nnr27                          -1.110223e-16                 0.006668
# nnr33                           0.000000e+00                 0.003138
# nnr36                           0.000000e+00                 0.000392
# nnr41                           0.000000e+00                 0.000294
#
#        sac_length_AOI_1[1]_max  sac_acceleration_AOI_1[1]_mean  \
# nnr26                 0.975820                        0.755757
# nnr27                 1.223697                        0.664412
# nnr33                 0.890220                       29.681030
# nnr36                 0.996313                        0.338206
# nnr41                 1.115643                        2.166084
#
#        sac_acceleration_AOI_1[1]_mean_shift_SentenceID  \
# nnr26                                        -0.077476
# nnr27                                        -0.145907
# nnr33                                        28.878591
# nnr36                                        -0.462028
# nnr41                                         1.321617
#
#        sac_acceleration_AOI_1[1]_mean_shift_SubjectID  \
# nnr26                                             0.0
# nnr27                                             0.0
# nnr33                                             0.0
# nnr36                                             0.0
# nnr41                                             0.0
#
#        sac_length_AOI_1[0]_min  sac_length_AOI_1[0]_max  \
# nnr26                 0.003824                 1.084462
# nnr27                 0.003726                 0.994940
# nnr33                 0.003334                 0.931010
# nnr36                 0.000000                 1.013276
# nnr41                 0.000098                 0.976506
#
#        sac_acceleration_AOI_1[0]_mean  \
# nnr26                        0.966335
# nnr27                        0.661719
# nnr33                        1.564360
# nnr36                        0.503107
# nnr41                       17.153674
#
#        sac_acceleration_AOI_1[0]_mean_shift_SentenceID  \
# nnr26                                         0.065272
# nnr27                                        -0.217515
# nnr33                                         0.641526
# nnr36                                        -0.355475
# nnr41                                        16.254921
#
#        sac_acceleration_AOI_1[0]_mean_shift_SubjectID
# nnr26                                             0.0
# nnr27                                             0.0
# nnr33                                             0.0
# nnr36                                             0.0
# nnr41                                             0.0

# %% [markdown]
# ##### 3.1.3. Три значения `AOI`. Ожидается: (1 фича + 2 shift фичи) x (2 + 3 + 3) = 24 для `AOI_1` $\in [0, 1]$, `AOI_2` $\in [11, 22, 33]$, `AOI_3` $\in [A, B, C]$.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats={'length': ['min']},
    shift_features={'length': ['min']},
    shift_pk=(['SentenceID'], ['SubjectID'])
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    aoi=['AOI_1', 'AOI_2', 'AOI_3'],
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.51it/s]
#        sac_length_AOI_1[1]_min  sac_length_AOI_1[1]_min_shift_SentenceID  \
# nnr26                 0.007354                                  0.003708
# nnr27                 0.006668                                  0.002867
# nnr33                 0.003138                                 -0.000435
# nnr36                 0.000392                                 -0.003506
# nnr41                 0.000294                                 -0.003470
#
#        sac_length_AOI_1[1]_min_shift_SubjectID  sac_length_AOI_1[0]_min  \
# nnr26                                      0.0                 0.003824
# nnr27                                      0.0                 0.003726
# nnr33                                      0.0                 0.003334
# nnr36                                      0.0                 0.000000
# nnr41                                      0.0                 0.000098
#
#        sac_length_AOI_1[0]_min_shift_SentenceID  \
# nnr26                                  0.000684
# nnr27                                  0.000309
# nnr33                                  0.000005
# nnr36                                 -0.003162
# nnr41                                 -0.003204
#
#        sac_length_AOI_1[0]_min_shift_SubjectID  sac_length_AOI_2[11]_min  \
# nnr26                                      0.0                  0.007354
# nnr27                                      0.0                  0.012649
# nnr33                                      0.0                  0.007746
# nnr36                                      0.0                  0.001275
# nnr41                                      0.0                  0.003040
#
#        sac_length_AOI_2[11]_min_shift_SentenceID  \
# nnr26                                  -0.001044
# nnr27                                   0.004437
# nnr33                                   0.000102
# nnr36                                  -0.007186
# nnr41                                  -0.005132
#
#        sac_length_AOI_2[11]_min_shift_SubjectID  sac_length_AOI_2[22]_min  \
# nnr26                                       0.0                  0.009021
# nnr27                                       0.0                  0.012747
# nnr33                                       0.0                  0.001667
# nnr36                                       0.0                  0.004216
# nnr41                                       0.0                  0.007158
#
#        ...  sac_length_AOI_2[33]_min_shift_SubjectID  sac_length_AOI_3[B]_min  \
# nnr26  ...                                       0.0                 0.009707
# nnr27  ...                                       0.0                 0.006864
# nnr33  ...                                       0.0                 0.005589
# nnr36  ...                                       0.0                 0.000784
# nnr41  ...                                       0.0                 0.000686
#
#        sac_length_AOI_3[B]_min_shift_SentenceID  \
# nnr26                                  0.001911
# nnr27                                 -0.000724
# nnr33                                 -0.002267
# nnr36                                 -0.006466
# nnr41                                 -0.006878
#
#        sac_length_AOI_3[B]_min_shift_SubjectID  sac_length_AOI_3[C]_min  \
# nnr26                                      0.0                 0.020199
# nnr27                                      0.0                 0.003726
# nnr33                                      0.0                 0.003334
# nnr36                                      0.0                 0.000392
# nnr41                                      0.0                 0.009707
#
#        sac_length_AOI_3[C]_min_shift_SentenceID  \
# nnr26                                  0.013485
# nnr27                                 -0.002898
# nnr33                                 -0.003114
# nnr36                                 -0.005543
# nnr41                                  0.002990
#
#        sac_length_AOI_3[C]_min_shift_SubjectID  sac_length_AOI_3[A]_min  \
# nnr26                                      0.0                 0.008825
# nnr27                                      0.0                 0.004608
# nnr33                                      0.0                 0.002745
# nnr36                                      0.0                 0.000294
# nnr41                                      0.0                 0.000882
#
#        sac_length_AOI_3[A]_min_shift_SentenceID  \
# nnr26                                  0.003830
# nnr27                                 -0.000427
# nnr33                                 -0.002134
# nnr36                                 -0.004878
# nnr41                                 -0.004309
#
#        sac_length_AOI_3[A]_min_shift_SubjectID
# nnr26                                      0.0
# nnr27                                      0.0
# nnr33                                      0.0
# nnr36                                      0.0
# nnr41                                      0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ##### 3.1.4. Три значения `AOI`. Ожидается: (1 фича + 2 shift фичи) x (2 + 3 + 3 + 1) = 27 для `AOI_1` $\in [0, 1]$, `AOI_2` $\in [11, 22, 33]$, `AOI_3` $\in [A, B, C]$, `calc_without_aoi=True`.

# %%
sf = eye_stats.SaccadeFeatures(
    features_stats={'length': ['min']},
    shift_features={'length': ['min']},
    shift_pk=(['SentenceID'], ['SubjectID']),
    calc_without_aoi=True
)

extractor = Extractor(
    features=[sf],
    x='x',
    y='x',
    t='timestamp',
    duration='duration',
    # dispersion='dispersion',
    # path_pk=['SubjectID'],
    aoi=['AOI_1', 'AOI_2', 'AOI_3'],
    pk=['SubjectID'],
    return_df=True
)

extractor.fit_transform(df).head()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.16it/s]
#        sac_length_min  sac_length_min_shift_SentenceID  \
# nnr26        0.000981                        -0.000083
# nnr27        0.000098                        -0.001024
# nnr33        0.001667                         0.000617
# nnr36        0.000000                        -0.001020
# nnr41        0.000098                        -0.001018
#
#        sac_length_min_shift_SubjectID  sac_length_AOI_1[1]_min  \
# nnr26                             0.0                 0.007354
# nnr27                             0.0                 0.006668
# nnr33                             0.0                 0.003138
# nnr36                             0.0                 0.000392
# nnr41                             0.0                 0.000294
#
#        sac_length_AOI_1[1]_min_shift_SentenceID  \
# nnr26                                  0.003708
# nnr27                                  0.002867
# nnr33                                 -0.000435
# nnr36                                 -0.003506
# nnr41                                 -0.003470
#
#        sac_length_AOI_1[1]_min_shift_SubjectID  sac_length_AOI_1[0]_min  \
# nnr26                                      0.0                 0.003824
# nnr27                                      0.0                 0.003726
# nnr33                                      0.0                 0.003334
# nnr36                                      0.0                 0.000000
# nnr41                                      0.0                 0.000098
#
#        sac_length_AOI_1[0]_min_shift_SentenceID  \
# nnr26                                  0.000684
# nnr27                                  0.000309
# nnr33                                  0.000005
# nnr36                                 -0.003162
# nnr41                                 -0.003204
#
#        sac_length_AOI_1[0]_min_shift_SubjectID  sac_length_AOI_2[11]_min  ...  \
# nnr26                                      0.0                  0.007354  ...
# nnr27                                      0.0                  0.012649  ...
# nnr33                                      0.0                  0.007746  ...
# nnr36                                      0.0                  0.001275  ...
# nnr41                                      0.0                  0.003040  ...
#
#        sac_length_AOI_2[33]_min_shift_SubjectID  sac_length_AOI_3[B]_min  \
# nnr26                                       0.0                 0.009707
# nnr27                                       0.0                 0.006864
# nnr33                                       0.0                 0.005589
# nnr36                                       0.0                 0.000784
# nnr41                                       0.0                 0.000686
#
#        sac_length_AOI_3[B]_min_shift_SentenceID  \
# nnr26                                  0.001911
# nnr27                                 -0.000724
# nnr33                                 -0.002267
# nnr36                                 -0.006466
# nnr41                                 -0.006878
#
#        sac_length_AOI_3[B]_min_shift_SubjectID  sac_length_AOI_3[C]_min  \
# nnr26                                      0.0                 0.020199
# nnr27                                      0.0                 0.003726
# nnr33                                      0.0                 0.003334
# nnr36                                      0.0                 0.000392
# nnr41                                      0.0                 0.009707
#
#        sac_length_AOI_3[C]_min_shift_SentenceID  \
# nnr26                                  0.013485
# nnr27                                 -0.002898
# nnr33                                 -0.003114
# nnr36                                 -0.005543
# nnr41                                  0.002990
#
#        sac_length_AOI_3[C]_min_shift_SubjectID  sac_length_AOI_3[A]_min  \
# nnr26                                      0.0                 0.008825
# nnr27                                      0.0                 0.004608
# nnr33                                      0.0                 0.002745
# nnr36                                      0.0                 0.000294
# nnr41                                      0.0                 0.000882
#
#        sac_length_AOI_3[A]_min_shift_SentenceID  \
# nnr26                                  0.003830
# nnr27                                 -0.000427
# nnr33                                 -0.002134
# nnr36                                 -0.004878
# nnr41                                 -0.004309
#
#        sac_length_AOI_3[A]_min_shift_SubjectID
# nnr26                                      0.0
# nnr27                                      0.0
# nnr33                                      0.0
# nnr36                                      0.0
# nnr41                                      0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Проверка названий фичей

# %%
extractor.features[0].feature_names_in_
# Out:
# ['sac_length_min',
#  'sac_length_min_shift_SentenceID',
#  'sac_length_min_shift_SubjectID',
#  'sac_length_AOI_1[1]_min',
#  'sac_length_AOI_1[1]_min_shift_SentenceID',
#  'sac_length_AOI_1[1]_min_shift_SubjectID',
#  'sac_length_AOI_1[0]_min',
#  'sac_length_AOI_1[0]_min_shift_SentenceID',
#  'sac_length_AOI_1[0]_min_shift_SubjectID',
#  'sac_length_AOI_2[11]_min',
#  'sac_length_AOI_2[11]_min_shift_SentenceID',
#  'sac_length_AOI_2[11]_min_shift_SubjectID',
#  'sac_length_AOI_2[22]_min',
#  'sac_length_AOI_2[22]_min_shift_SentenceID',
#  'sac_length_AOI_2[22]_min_shift_SubjectID',
#  'sac_length_AOI_2[33]_min',
#  'sac_length_AOI_2[33]_min_shift_SentenceID',
#  'sac_length_AOI_2[33]_min_shift_SubjectID',
#  'sac_length_AOI_3[B]_min',
#  'sac_length_AOI_3[B]_min_shift_SentenceID',
#  'sac_length_AOI_3[B]_min_shift_SubjectID',
#  'sac_length_AOI_3[C]_min',
#  'sac_length_AOI_3[C]_min_shift_SentenceID',
#  'sac_length_AOI_3[C]_min_shift_SubjectID',
#  'sac_length_AOI_3[A]_min',
#  'sac_length_AOI_3[A]_min_shift_SentenceID',
#  'sac_length_AOI_3[A]_min_shift_SubjectID']
